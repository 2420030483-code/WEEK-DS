# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('train.csv')
plt.hist(df['Temperature'],color='red')
plt.title("histogram")
plt.xlabel("value range")
plt.ylabel("frequency")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df=pd.read_csv('/content/train.csv')
plt.boxplot(df['Temperature'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7bd797053650>,
#   <matplotlib.lines.Line2D at 0x7bd797051940>],
#  'caps': [<matplotlib.lines.Line2D at 0x7bd797050800>,
#   <matplotlib.lines.Line2D at 0x7bd797052e70>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7bd797052480>],
#  'medians': [<matplotlib.lines.Line2D at 0x7bd7a5e00800>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7bd797052000>],
#  'means': []}
